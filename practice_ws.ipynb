# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import datetime
import csv

# %% [markdown]
# ##### Extract, Transform, and Load

# %%
def extract(page):
    '''Call this function first'''
    headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.71 Safari/537.36'}
    if page == 0:
        url = 'https://www.indeed.com/jobs?q=data+analyst&jt=fulltime&explvl=entry_level&fromage=7'
    else:
        url = f'https://www.indeed.com/jobs?q=data+analyst&jt=fulltime&explvl=entry_level&fromage=7&start={page}'
    
    response = requests.get(url,headers)
    soup = BeautifulSoup(response.content, 'html.parser')

    return soup

def extract_expand(href_list):
    '''This function third'''
    headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.71 Safari/537.36'}
    
    for href_item in href_list:
        url = f'https://www.indeed.com{href_item}'
        response = requests.get(url,headers)
        soup = BeautifulSoup(response.content, 'html.parser')
        soup_list.append(soup)
    return
def transform(soup):
    '''This function second'''
    divs = soup.find_all('div', class_='mosaic-zone', id="mosaic-zone-jobcards")
    for item in divs:
        urls = item.find_all('a', id=True, class_=True, href=True)
        for href in urls:
            href_list.append(href['href'])
    return

def transform_expand(soup, href):
    '''This one should be called in the extract_expand func'''
    divs = soup.find_all('div', class_='icl-Container--fluid fs-unmask jobsearch-ViewJobLayout-fluidContainer is-US icl-u-xs-p--sm')
    date = datetime.datetime.now()
    date = int(date.strftime('%Y%m%d'))
    
    for item in divs:
        title = item.find('h1').text
        company = item.find('div', class_='icl-u-lg-mr--sm icl-u-xs-mr--xs').text
        job_description = item.find('div', id='jobDescriptionText', class_='jobsearch-jobDescriptionText')

        p_list = []
        li_list = []

        for p_tags in job_description.find_all('p'):
            p_list.append(p_tags.text.replace('\n', ' '))
        for li_tags in job_description.find_all('li'):
            li_list.append(li_tags.text.replace('\n', ' '))

        p_li_list = p_list + li_list
        description = ' '.join(map(str, p_li_list))
        website = 'www.indeed.com' + href

        job = {
            'job_title' : title,
            'company' : company,
            'job_description' : description,
            'website' : website,
            'date_scraped' : date

        }
        job_list.append(job)
    return

# %% [markdown]
# ##### Cleaning DataFrame

# %%
try:
    filepath = 'indeed_jobs.csv'
    df = pd.read_csv(filepath).drop('Unnamed: 0', axis=1)
except:
    df = pd.DataFrame()

# %%
for i in range (0,40,10):
    href_list = []
    soup_list = []
    job_list = []
    a = 0

    info_extracted = extract(i)
    transform(info_extracted)
    extract_expand(href_list)

    for soup in soup_list:
        transform_expand(soup, href_list[a])
        df = df.append(job_list, ignore_index=True)
        a += 1
        df

# %%
df
# Out:
#                              job_title                                company  \
# 0       Junior Investment Data Analyst            ACR Alpine Capital Research
# 1       Junior Investment Data Analyst            ACR Alpine Capital Research
# 2           Data Analyst *ENTRY LEVEL*                        CCS Global Tech
# 3       Junior Investment Data Analyst            ACR Alpine Capital Research
# 4           Data Analyst *ENTRY LEVEL*                        CCS Global Tech
# ..                                 ...                                    ...
# 475         Public Health Data Analyst               Lantana Consulting Group
# 476                   Business Analyst                                 Photon
# 477                       Data Analyst  University of Arkansas at Little Rock
# 478             Data Analytics Analyst              American Transmission Co.
# 479  Junior Associate - Data Analytics                     The Parkside Group
#
#                                        job_description  \
# 0    JOB TITLE: Junior Investment Data Analyst Loca...
# 1    JOB TITLE: Junior Investment Data Analyst Loca...
# 2    Responsibilities Skills Job Types: Full-time, ...
# 3    JOB TITLE: Junior Investment Data Analyst Loca...
# 4    Responsibilities Skills Job Types: Full-time, ...
# ..                                                 ...
# 475  Company: Lantana Consulting Group provides ser...
# 476
# 477   Bachelor’s degree in management information s...
# 478    Essential Responsibilities:   In this role, ...
# 479  The Parkside Group is a full-service public af...
#
#                                                website  date_scraped
# 0    www.indeed.com/pagead/clk?mo=r&ad=-6NYlbfkN0AS...      20220121
# 1    www.indeed.com/pagead/clk?mo=r&ad=-6NYlbfkN0AS...      20220121
# 2    www.indeed.com/company/CCS-Global-Tech/jobs/Da...      20220121
# 3    www.indeed.com/pagead/clk?mo=r&ad=-6NYlbfkN0AS...      20220121
# 4    www.indeed.com/company/CCS-Global-Tech/jobs/Da...      20220121
# ..                                                 ...           ...
# 475  www.indeed.com/company/Lantana-Consulting-Grou...      20220121
# 476  www.indeed.com/rc/clk?jk=3a318d52ed46bd08&fcci...      20220121
# 477  www.indeed.com/rc/clk?jk=6084324059483b93&fcci...      20220121
# 478  www.indeed.com/rc/clk?jk=ba39cb26474e1571&fcci...      20220121
# 479  www.indeed.com/company/The-Parkside-Group/jobs...      20220121
#
# [480 rows x 5 columns]

# %%
df_nodups = df.drop_duplicates(subset=['job_title', 'company', 'job_description'], keep='last')

# %%
df_indexfixed = df_nodups.reset_index(drop=True)

# %%
df_indexfixed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   job_title        50 non-null     object
#  1   company          50 non-null     object
#  2   job_description  50 non-null     object
#  3   website          50 non-null     object
#  4   date_scraped     50 non-null     int64
# dtypes: int64(1), object(4)
# memory usage: 2.1+ KB

# %%
df_indexfixed
# Out:
#                                             job_title  \
# 0                      Junior Investment Data Analyst
# 1                    Sports Gaming Data Entry Analyst
# 2                              Workforce Data Analyst
# 3                                        Data Analyst
# 4                                      Data Analyst 2
# 5                                    Jr. Data Analyst
# 6                                        Data Analyst
# 7                        Entry Level Business Analyst
# 8                       Junior Data Analyst (Banking)
# 9                                     Data Specialist
# 10                                       Data Analyst
# 11                                      Analyst, Data
# 12                                       Data Analyst
# 13                          Research and Data Analyst
# 14        Associate Compliance Analyst (Data Removal)
# 15                                   ANALYST DATA CMG
# 16                                       Data Analyst
# 17      Assistant Data Analyst, Rankings and Contests
# 18                                       Data Analyst
# 19                         Data Analyst *ENTRY LEVEL*
# 20                       Entry Level Business Analyst
# 21                                Junior Data Analyst
# 22                              Data Analyst (ONSITE)
# 23                                       Data Analyst
# 24                        Data Analyst (Immunization)
# 25                                 Data Entry Analyst
# 26                            Research Data Analyst 1
# 27                                   Business Analyst
# 28                                    Data Analyst II
# 29                                       Data Analyst
# 30                            Research Data Analyst 2
# 31                            Operations/Data Analyst
# 32                                   Jr. Data Analyst
# 33                              Research Data Analyst
# 34                                       Data Analyst
# 35                               Data Modeler Analyst
# 36  Associate Data Analyst - Finance (m/f/d) - REMOTE
# 37                                       Data Analyst
# 38                                       Data Analyst
# 39                                       Data Analyst
# 40  Data & Reporting Analyst - Personal Lines P&C ...
# 41  Trade Data Analyst - SQL or Power BI Experienc...
# 42                                     Data Analyst 1
# 43                                       Data Analyst
# 44                                 Data Entry Analyst
# 45                         Public Health Data Analyst
# 46                                   Business Analyst
# 47                                       Data Analyst
# 48                             Data Analytics Analyst
# 49                  Junior Associate - Data Analytics
#
#                                               company  \
# 0                         ACR Alpine Capital Research
# 1                       Sports Gaming Technology Firm
# 2   California Public Employees' Retirement System...
# 3                                            PC Matic
# 4                                              PayPal
# 5                                          Ignite Tek
# 6                             City Ranked Media, Inc.
# 7                                     Cloudinfraspecs
# 8                                  Invexer Technology
# 9                            Thompson School District
# 10                        Intelligent Medical Objects
# 11                                  Molina Healthcare
# 12                                    Orlando City SC
# 13                                      ESC Region 11
# 14                                           Deloitte
# 15                                      Centra Health
# 16                                     Cannabis Cured
# 17                                          BNP Media
# 18                       Nuvia Dental Implant Centers
# 19                                    CCS Global Tech
# 20                                      Dhatronictech
# 21                                    CCS Global Tech
# 22                   Starcrest Products Of California
# 23                                      Primary Color
# 24             Government of the District of Columbia
# 25                                         GreenCoast
# 26                                Stanford University
# 27                                          Accenture
# 28                          Mount Sinai Health System
# 29                                       Baker Hughes
# 30                    University of California, Davis
# 31                                  Spectrum Comm Inc
# 32                              Vallarta Supermarkets
# 33             University of California San Francisco
# 34                                             Crumbl
# 35                                      Econtenti Inc
# 36                                 Tier Mobility GmbH
# 37                        Altair Data Resources, Inc.
# 38                              Reynolds and Reynolds
# 39                    Workforce Enterprises WFE, Inc.
# 40                        The Hanover Insurance Group
# 41                                             Kroger
# 42                                         Intellimed
# 43                                          Red Robin
# 44                                        Alera Group
# 45                           Lantana Consulting Group
# 46                                             Photon
# 47              University of Arkansas at Little Rock
# 48                          American Transmission Co.
# 49                                 The Parkside Group
#
#                                       job_description  \
# 0   JOB TITLE: Junior Investment Data Analyst Loca...
# 1   Sports Gaming Data Entry Analyst in Arlington,...
# 2   The California Public Employees’ Retirement Sy...
# 3   PC Matic, a leading cybersecurity company that...
# 4   Who we are: At PayPal (NASDAQ: PYPL), we belie...
# 5   The Researcher / Junior Strategist (RJS) perfo...
# 6   Do you love digging into data to draw conclusi...
# 7   We are seeking a Talented and Driven Business ...
# 8   Contract duration: long-term visa: H1b, US cit...
# 9                                         JobID: 9803
# 10  Research shows that women and underrepresented...
# 11
# 12  Plans, oversees, and coordinates the analysis ...
# 13  Job Title: Research and Data Analyst  Division...
# 14   Review requests to remove personal data from ...
# 15  Partnering with you to live your best life. At...
# 16  The Company The Maine Cannabis Campus is the f...
# 17  Engineering News-Record (ENR), the leading sou...
# 18  Nuvia Dental Implant Center, a growing dental ...
# 19  Responsibilities Skills Job Types: Full-time, ...
# 20  We are looking for Entry Level Business Analys...
# 21  As a junior data analyst, you will manage data...
# 22  Job description Do you enjoy working with numb...
# 23  We are seeking a Data Analysis Expert to join ...
# 24   Bring your professional career to Washington,...
# 25  GreenCoast is looking for a self-motivated, fo...
# 26  The Brain Dynamics Lab (BDL) within the Depart...
# 27  Minimum Qualifications Microsoft Excel Google ...
# 28  We are seeking a Data Analyst(Research Analyst...
# 29  Data Analyst- Pipeline Inspection (ILI)  Do yo...
# 30  Bachelor’s degree or extensive coursework in s...
# 31  Spectrum is seeking highly qualified Analysts ...
# 32  Title: Jr. Data Analyst | Asset ProtectionClas...
# 33   Department Description Required Qualification...
# 34   Data Analyst  Join Crumbl Corporate in making...
# 35  The Expertise Required The Necessary SkillsAs ...
# 36  THIS IS US  TIER Mobility is Europe's leading ...
# 37    Altair Data Resources is seeking an entry-le...
# 38  The Data Analyst is responsible for collecting...
# 39  Workforce Enterprises is seeking a Data Analys...
# 40  Analyze loss ratio and production trends at th...
# 41  Company Name: Kroger Specialty Pharmacy  Posit...
# 42  Please No H1-B applicants SUMMARY  The Data An...
# 43   The Data Analyst will design, develop, and su...
# 44  Vital Incite an Alera Group company is looking...
# 45  Company: Lantana Consulting Group provides ser...
# 46
# 47   Bachelor’s degree in management information s...
# 48    Essential Responsibilities:   In this role, ...
# 49  The Parkside Group is a full-service public af...
#
#                                               website  date_scraped
# 0   www.indeed.com/pagead/clk?mo=r&ad=-6NYlbfkN0AS...      20220121
# 1   www.indeed.com/pagead/clk?mo=r&ad=-6NYlbfkN0Cn...      20220121
# 2   www.indeed.com/company/California-Public-Emplo...      20220121
# 3   www.indeed.com/company/PC-Matic/jobs/Data-Anal...      20220121
# 4   www.indeed.com/rc/clk?jk=76ad377b677f0b5c&fcci...      20220121
# 5   www.indeed.com/company/Ignite-Tek/jobs/Junior-...      20220121
# 6   www.indeed.com/company/City-Ranked-Media,-Inc....      20220121
# 7   www.indeed.com/company/Cloudinfraspecs/jobs/En...      20220121
# 8   www.indeed.com/company/Invexer-Technology/jobs...      20220121
# 9   www.indeed.com/rc/clk?jk=7ad9e941e8fc14f4&fcci...      20220121
# 10  www.indeed.com/company/Intelligent-Medical-Obj...      20220121
# 11  www.indeed.com/rc/clk?jk=2c3d8994df33aff4&fcci...      20220121
# 12  www.indeed.com/rc/clk?jk=de71d2fbb8ea079d&fcci...      20220121
# 13  www.indeed.com/rc/clk?jk=bf3f4b8e6024fd97&fcci...      20220121
# 14  www.indeed.com/rc/clk?jk=06a9645ccc0cb7e3&fcci...      20220121
# 15  www.indeed.com/rc/clk?jk=a29fa2b7c98488d4&fcci...      20220121
# 16  www.indeed.com/company/Green-Alien-Cannabis/jo...      20220121
# 17  www.indeed.com/company/BNP-Media/jobs/Assistan...      20220121
# 18  www.indeed.com/rc/clk?jk=710c31ba279b7a40&fcci...      20220121
# 19  www.indeed.com/company/CCS-Global-Tech/jobs/Da...      20220121
# 20  www.indeed.com/company/Dhatronictech/jobs/Entr...      20220121
# 21  www.indeed.com/company/CCS-Global-Tech/jobs/Ju...      20220121
# 22  www.indeed.com/company/Starcrest-Products-Of-C...      20220121
# 23  www.indeed.com/company/Primary-Color/jobs/Data...      20220121
# 24  www.indeed.com/rc/clk?jk=6c6c82cc5d4e9c1d&fcci...      20220121
# 25  www.indeed.com/company/GreenCoast/jobs/Data-En...      20220121
# 26  www.indeed.com/rc/clk?jk=30b69b6bbc223c91&fcci...      20220121
# 27  www.indeed.com/rc/clk?jk=81ec0e67649cf81d&fcci...      20220121
# 28  www.indeed.com/company/Mount-Sinai-Health-Syst...      20220121
# 29  www.indeed.com/rc/clk?jk=55611b9bc60b468b&fcci...      20220121
# 30  www.indeed.com/rc/clk?jk=308812e107ad891b&fcci...      20220121
# 31  www.indeed.com/company/Spectrum-Comm-Inc/jobs/...      20220121
# 32  www.indeed.com/company/Vallarta-Supermarkets/j...      20220121
# 33  www.indeed.com/rc/clk?jk=72d219a5fc241175&fcci...      20220121
# 34  www.indeed.com/rc/clk?jk=9f33ec4c2046ef69&fcci...      20220121
# 35  www.indeed.com/company/Econtenti-Inc/jobs/Data...      20220121
# 36  www.indeed.com/rc/clk?jk=4dd26cd2a454a418&fcci...      20220121
# 37  www.indeed.com/rc/clk?jk=28ea40bd2b1e76da&fcci...      20220121
# 38  www.indeed.com/rc/clk?jk=fb22b1191b6bf764&fcci...      20220121
# 39  www.indeed.com/company/Workforce-Enterprises-W...      20220121
# 40  www.indeed.com/rc/clk?jk=ab0c3c9c9cdc7464&fcci...      20220121
# 41  www.indeed.com/rc/clk?jk=e50a41a811d0f8cb&fcci...      20220121
# 42  www.indeed.com/company/Intellimed/jobs/Data-An...      20220121
# 43  www.indeed.com/rc/clk?jk=d0897c7f3219a49b&fcci...      20220121
# 44  www.indeed.com/company/Alera-Group/jobs/Data-E...      20220121
# 45  www.indeed.com/company/Lantana-Consulting-Grou...      20220121
# 46  www.indeed.com/rc/clk?jk=3a318d52ed46bd08&fcci...      20220121
# 47  www.indeed.com/rc/clk?jk=6084324059483b93&fcci...      20220121
# 48  www.indeed.com/rc/clk?jk=ba39cb26474e1571&fcci...      20220121
# 49  www.indeed.com/company/The-Parkside-Group/jobs...      20220121

# %%
df_indexfixed.to_csv('indeed_jobs.csv', mode='a', header=False)
