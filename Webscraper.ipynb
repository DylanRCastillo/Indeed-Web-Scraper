# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# ##### Extract, Transform, and Load

# %%
def extract(page):
    headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.71 Safari/537.36'}
    url = ''
    if page == 0:
        url = 'https://www.indeed.com/jobs?q=data+analyst&jt=fulltime&explvl=entry_level&fromage=7'
    else:
        url = f'https://www.indeed.com/jobs?q=data+analyst&jt=fulltime&explvl=entry_level&fromage=7&start={page}'
    
    response = requests.get(url,headers)
    soup = BeautifulSoup(response.content, 'html.parser')

    return soup

# %%
def transform(soup):

    divs = soup.find_all('div', class_='job_seen_beacon')
    for item in divs:
        title = item.find('h2').text.split('new')[1].strip()
        company = item.find('span', class_='companyName').text.strip()
        summary = item.find('li').text.strip().replace('\n', '')
        day = item.find('span', class_='date').text.strip()
        try:
            attribute = item.find('div', class_='attribute_snippet').text.strip()
        except:
            attribute = ''
        
        job = {
            'title' : title,
            'company': company,
            'summary': summary,
            'attribute':attribute
        }
        job_list.append(job)
    return

# %%
# Out:
# EmployerActive 3 days ago
# Posted1 day ago
# PostedToday
# Posted5 days ago
# PostedJust posted
# Posted2 days ago
# PostedToday
# PostedToday
# PostedToday
# Posted1 day ago
# PostedToday
# Posted6 days ago
# Posted2 days ago
# Posted2 days ago
# PostedToday

# %%
job_list = []
for i in range(0,40,10):
    info_extracted = extract(i)
    transform(info_extracted)
df = pd.DataFrame(job_list)
df
# Out:
#                                                 title  \
# 0                                        Data Analyst
# 1                                        Data Analyst
# 2                                 Data Analyst/Remote
# 3                                        Data Analyst
# 4                                        Data Analyst
# 5                                       Analyst, Data
# 6                                        Data Analyst
# 7   Excel Specialist for Data Analyst Role at E-Co...
# 8        Associate Data Analyst (Remote - Nationwide)
# 9   Data Analyst - Merchandising (Full-Time Remote...
# 10       Data Analyst I / 40 Hours/ MGH- Primary Care
# 11                               Data Analyst-Quality
# 12  Entry Level Position / Free Bootcamp - Data En...
# 13                                       Data Analyst
# 14                                       Data Analyst
# 15                                       Data Analyst
# 16                                       Data Analyst
# 17                                   Business Analyst
# 18                                Junior Data Analyst
# 19                                    Data Analyst-BA
# 20                                       Data Analyst
# 21                                       Data Analyst
# 22                 Sky Harbor Data Analyst-- $30/hour
# 23                             IT Claims Data Analyst
# 24  Litigation Data Analyst - 2nd Shift (Remote Op...
# 25                                       Data Analyst
# 26                      BUSINESS INTELLIGENCE ANALYST
# 27                                    IGAMING ANALYST
# 28                                       Data Analyst
# 29              Business Analyst (must speak Spanish)
# 30                                       Data Analyst
# 31              Business Analyst (must speak Spanish)
# 32              Data Analyst Junior (Neuropsychiatry)
# 33                           Systems and Data Analyst
# 34                               Data Analyst- Remote
# 35                                       Data Analyst
# 36                                       Data Analyst
# 37                                Junior Data Analyst
# 38             Data Analyst - Office of Financial Aid
# 39                      Business Intelligence Analyst
# 40         Data Analyst - Hotel Analytics and Support
# 41                                Health Data Analyst
# 42                            Data Analyst (Listings)
# 43     Cannabis Operations & Data Analytics Associate
# 44                               Jr. Business Analyst
# 45                                       Data Analyst
# 46                             Marketing Data Analyst
# 47                        Apprentice Business Analyst
# 48         Data Analyst, Cancer and Mortality Studies
# 49                                       Data Analyst
# 50                              Research Data Analyst
# 51                                Collections Analyst
# 52                                       Data Analyst
# 53                                       Data Analyst
# 54                                       Data Analyst
# 55                                       Data Analyst
# 56                                Junior Data Analyst
# 57                                       Data Analyst
# 58     Data Analyst (Job ID: 51961, Apply by 1/18/22)
# 59                       GIS Developer & Data Analyst
#
#                                       company  \
# 0                                 Brooksource
# 1                                      PRIMUS
# 2                  CDC Foundation ( Contract)
# 3                           System Innovators
# 4                     LightBox Employer L L C
# 5                           Molina Healthcare
# 6                  Atlas Executive Consulting
# 7                          The Elite Team Inc
# 8                                     Lumeris
# 9                                      TARGET
# 10        Massachusetts General Hospital(MGH)
# 11                    MSO of Puerto Rico, LLC
# 12                            PCS Global Tech
# 13                                    Cianbro
# 14                           Northwell Health
# 15                                    Cianbro
# 16                           Northwell Health
# 17                                  RentMoola
# 18                              FocusKPI Inc.
# 19                                Exavalu Inc
# 20                         Partners In Health
# 21                                  RiverBank
# 22               Ace Parking Management, Inc.
# 23         Corporate Systems Associates, Inc.
# 24                                KLDiscovery
# 25                                        ACV
# 26                               Jamul Casino
# 27                                 DraftKings
# 28                           Intellipro Group
# 29                       IntegrateUs Services
# 30                           Intellipro Group
# 31                       IntegrateUs Services
# 32                 University of Pennsylvania
# 33                     Acutis Diagnostics Inc
# 34                        Next Gear Solutions
# 35                       Brookside Properties
# 36                   SEARCH Homeless Services
# 37                     OH Predictive Insights
# 38                           Emory University
# 39                                    REVOLVE
# 40                      Peachtree Hotel Group
# 41               NextGen information services
# 42                  reibus International, Inc
# 43                              Sundae School
# 44                  Quantum Technologies Inc.
# 45                      City of Rochester, NY
# 46                                ROI ADS LLC
# 47                    Public Consulting Group
# 48                                NYC Careers
# 49  VNA & Hospice of the Southwest Region Inc
# 50                        Stanford University
# 51                      PowerSchool Group LLC
# 52                     Boyd Caton Group (bcg)
# 53                        Qi Venture Partners
# 54            Shriners Hospitals for Children
# 55                                 EmployIndy
# 56                            CCS Global Tech
# 57                             PointClickCare
# 58     Minnesota Department of Transportation
# 59                LongPath Technologies, Inc.
#
#                                               summary  \
# 0   Extract and analyze data sets from various dat...
# 1   Adding more data and updating data to build da...
# 2   Perform basic data management, data cleaning a...
# 3   Develop database objects and scripts to load d...
# 4   1-3 of data analytics (educational or professi...
# 5   Job Summary Designs and implements processes a...
# 6    Develop and maintain databases and data systems.
# 7   The Data Analyst will be analyzing advertising...
# 8   Continues to dig for information beyond typica...
# 9   Merchandising teams rely on this team of analy...
# 10  The Data Analyst will ensure accuracy of data,...
# 11  We're committed to bringing passion and custom...
# 12  Provides plan with data, reporting, and analys...
# 13  Organize available data across 6+ data reposit...
# 14  Identifies issues in data quality that would i...
# 15  Organize available data across 6+ data reposit...
# 16  Identifies issues in data quality that would i...
# 17  1-3 years’ experience as a Business Analyst in...
# 18  Experience deriving actionable insights from d...
# 19  Data Mapping experience in mapping Legacy data...
# 20  Conduct regular data cleaning and implement da...
# 21  Compile data from a variety of existing system...
# 22  Demonstrated critical thinking and analytical ...
# 23  ETL and data processing development includes o...
# 24  In addition, through its global Ontrack Data R...
# 25  MS in a STEM discipline such statistics, compu...
# 26  Ability to collect relevant data, structure da...
# 27  1+ years of business analytics or data science...
# 28  Data analysis/business intelligence related: 3...
# 29                   Bilingual (English and Spanish).
# 30  Data analysis/business intelligence related: 3...
# 31                   Bilingual (English and Spanish).
# 32  Other duties might include: performing data ma...
# 33  Understand manage and architect data flow betw...
# 34  Acquire data from primary or secondary data so...
# 35  Handle multiple simultaneous data and reportin...
# 36                    Be familiar with data modeling.
# 37  Analyze quantitative research data (including ...
# 38  Creates and maintains a data dictionary and me...
# 39  Generate analysis and develop key insights fro...
# 40  Extract data from multiple system resources, i...
# 41  Trains and coaches less-experienced healthcare...
# 42  Foundational understanding of data and process...
# 43  California-based Cannabis Operations & Data An...
# 44  Knowledge of business process analysis, requir...
# 45  PLUS two (2) years of direct, practical experi...
# 46  For querying huge data sets, intermediate to a...
# 47  A detail oriented problem solving approach to ...
# 48  Facilitate use of matched cancer and mortality...
# 49  2-3 year experience working with healthcare da...
# 50           Analyze data processes in documentation.
# 51  1-3 years’ prior experience in a business or d...
# 52  Supporting training for industry stakeholders ...
# 53                 Collecting and reporting new data.
# 54  Pull and integrate data from disparate sources...
# 55  Prepares reports of data findings, illustratin...
# 56  As a junior data analyst, you will manage data...
# 57  Visualize data to develop a better understandi...
# 58     Gather, format and interpret statistical data;
# 59  Internal data management & streamlining of dat...
#
#                      attribute
# 0
# 1   $100,000 - $115,000 a year
# 2     $66,000 - $72,000 a year
# 3
# 4
# 5
# 6
# 7            $28 - $35 an hour
# 8
# 9
# 10
# 11
# 12    $60,000 - $72,000 a year
# 13
# 14
# 15
# 16
# 17
# 18
# 19   $70,000 - $120,000 a year
# 20    $50,000 - $60,000 a year
# 21         From $50,000 a year
# 22                 $30 an hour
# 23           $35 - $55 an hour
# 24
# 25
# 26
# 27
# 28
# 29           $50 - $55 an hour
# 30
# 31           $50 - $55 an hour
# 32
# 33
# 34    $55,000 - $85,000 a year
# 35        Up to $55,000 a year
# 36    $75,000 - $80,000 a year
# 37    $36,000 - $42,000 a year
# 38
# 39
# 40
# 41   $80,000 - $120,000 a year
# 42
# 43         From $65,000 a year
# 44    $50,000 - $75,000 a year
# 45    $69,428 - $91,545 a year
# 46   $47,115 - $110,957 a year
# 47                   Full-time
# 48    $75,504 - $93,776 a year
# 49     $31.77 - $44.48 an hour
# 50                   Full-time
# 51                   Full-time
# 52              $47,500 a year
# 53    $60,000 - $70,000 a year
# 54                   Full-time
# 55                   Full-time
# 56    $60,000 - $65,000 a year
# 57                   Full-time
# 58        Up to $75,418 a year
# 59    $60,000 - $78,000 a year

# %%
df.to_csv('indeed_jobs.csv', index=False)
